# %%
def test_demo():
  print('Funzt')

# %%
import sys
sys.path.append('/content/drive/MyDrive/Master_AI/AIVP/Project/Preprocessing')

# %%
import os
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import copy

# %%
import demo
demo.test_demo()
# Out:
# Funzt
